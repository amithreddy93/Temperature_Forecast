# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv(r"C:\Users\AMITHK\Downloads\Data Trained\Projects\Week 3\Temperature Prediction\temperature.csv")
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7677.000000  ...  7677.000000  7677.000000  7677.000000  7752.000000
# mean      0.368774  ...     0.485003     0.278200     0.269407    37.544722
# std       0.262458  ...     1.762807     1.161809     1.206214     0.050352
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146654  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315697  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.575489  ...     0.018364     0.007896     0.000041    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7752.000000  7752.000000  7752.000000      7752.000000  7725.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.128010
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
#          Next_Tmin
# count  7725.000000
# mean     22.932220
# std       2.487613
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
# Since Temperature can be forecasted based on the inputs date column can be dropped

df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 24 columns]

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter',x='lat',y='lon')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='lat', ylabel='lon'>

# %%
import seaborn as sns
plt.figure(figsize = (15,7))
sns.heatmap(df.corr() , annot = True, cmap="tab20c")
sns.set(font_scale=.5)
plt.show()

# %%
df.isnull().sum()
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df = df.dropna()

# %%
# Trying Kmeans for the first time to see the results only
from sklearn.cluster import KMeans
from sklearn import metrics

y = df.drop(['Next_Tmax','Next_Tmin'],axis=1)
score_dict = {}
for i in range(2,18):
    km = KMeans(n_clusters=i,random_state=1)
    l = km.fit_predict(y)
    s_s = metrics.silhouette_score(y,l)
    score_dict[i] =[s_s]

score_dict
# Out:
# {2: [0.629452650848032],
#  3: [0.5595087037487075],
#  4: [0.5063683706815555],
#  5: [0.464018245633451],
#  6: [0.4163813179785464],
#  7: [0.3878648119590528],
#  8: [0.3871447087716537],
#  9: [0.3705087169895706],
#  10: [0.35052805889671024],
#  11: [0.3581313237476393],
#  12: [0.33502245132027114],
#  13: [0.3208023215982904],
#  14: [0.32637305850227866],
#  15: [0.32958233301513223],
#  16: [0.3347047949320013],
#  17: [0.3145924933030152]}

# %%
kmeans_model = KMeans(n_clusters=3,max_iter=300,random_state=1)
dist = kmeans_model.fit_transform(y)

labels = kmeans_model.labels_
colormap = np.array(['r', 'g', 'b'])
plt.scatter(dist[:,0],dist[:,1],c=colormap[labels])
plt.title('Kmeans Clusters')
plt.show()

# %%
df['labels'] = labels
# Out:
# <ipython-input-65-d85224286460>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['labels'] = labels

# %%
df.merge(df['labels']).groupby('labels').mean()
# Out:
#           station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# labels
# 0       13.086781     31.058948     24.470189    56.278849    88.548502
# 1       12.902446     29.204048     22.850773    59.758451    89.137632
# 2       13.144438     29.206807     22.306530    51.302764    86.600721
#
#         LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  LDAPS_CC1  \
# labels
# 0              31.046298         24.825549  6.708278  64.991850   0.333301
# 1              29.183366         23.333442  7.457856  60.344051   0.423061
# 2              28.724587         22.245910  6.852906  63.645950   0.304464
#
#         ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4        lat         lon  \
# labels  ...
# 0       ...    0.324651    0.216695    0.147884  37.544378  126.991194
# 1       ...    0.688895    0.239766    0.313032  37.545957  126.991703
# 2       ...    0.263098    0.416144    0.316158  37.543011  126.991141
#
#               DEM     Slope  Solar radiation  Next_Tmax  Next_Tmin
# labels
# 0       60.903657  1.247346      5249.511506  31.629856  24.211196
# 1       63.855122  1.281936      5724.077259  29.738459  22.680039
# 2       59.353855  1.231365      4710.970054  29.523077  21.764638
#
# [3 rows x 24 columns]

# %%
df.groupby('labels').agg('count')['Next_Tmax'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='labels'>

# %%
df.groupby('labels').agg('count')['Next_Tmin'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='labels'>

# %% [markdown]
# # Modeling Our Data

# %%
df = df.drop(['labels'],axis=1)

# %%
from sklearn.model_selection import train_test_split

X=df.drop(['Next_Tmax','Next_Tmin'],axis=1)
y=df[['Next_Tmax','Next_Tmin']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 42)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import classification_report

LRmodel = LinearRegression()
LRmodel.fit(X_train,y_train)
predictions = LRmodel.predict(X_test)
test_score = r2_score(y_test,predictions)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
print("The accuracy of testing dataset ",test_score*100)
print('MAE for testing set: {}'.format(mean_absolute_error(predictions,y_test)))
print('MSE for testing set: {}'.format(mean_squared_error(predictions,y_test)))
print('RMSE for testing set: {}'.format(np.sqrt(mean_squared_error(predictions,y_test))))
# Out:
# The accuracy of testing dataset  80.88519621252539
# MAE for testing set: 0.9327706020233378
# MSE for testing set: 1.538290096257172
# RMSE for testing set: 1.2402782334045743

# %%
# Compare against actual values
df_predictions = pd.DataFrame(predictions)
df_predictions
# Out:
#               0          1
# 0     28.320791  24.333176
# 1     25.888545  21.742869
# 2     33.372845  23.606615
# 3     27.546296  22.409665
# 4     28.418891  23.021415
# ...         ...        ...
# 2272  32.990108  23.754411
# 2273  33.174499  24.858465
# 2274  32.342308  24.334171
# 2275  30.771047  21.155173
# 2276  27.615212  24.170163
#
# [2277 rows x 2 columns]

# %%
df_test = y_test.reset_index(drop=True)
df_test
# Out:
#       Next_Tmax  Next_Tmin
# 0          28.7       24.5
# 1          27.8       21.5
# 2          33.6       24.7
# 3          25.5       22.5
# 4          29.4       23.3
# ...         ...        ...
# 2272       32.7       22.2
# 2273       34.7       24.9
# 2274       32.6       23.7
# 2275       28.6       21.1
# 2276       28.2       24.1
#
# [2277 rows x 2 columns]

# %%
results = pd.DataFrame({'Actual Next_Tmax':df_test['Next_Tmax'],'Predicted Next_Tmax':df_predictions[0],
                       'Actual Next_Tmin':df_test['Next_Tmin'],'Predicted Next_Tmin':df_predictions[1]})
results
# Out:
#       Actual Next_Tmax  Predicted Next_Tmax  Actual Next_Tmin  \
# 0                 28.7            28.320791              24.5
# 1                 27.8            25.888545              21.5
# 2                 33.6            33.372845              24.7
# 3                 25.5            27.546296              22.5
# 4                 29.4            28.418891              23.3
# ...                ...                  ...               ...
# 2272              32.7            32.990108              22.2
# 2273              34.7            33.174499              24.9
# 2274              32.6            32.342308              23.7
# 2275              28.6            30.771047              21.1
# 2276              28.2            27.615212              24.1
#
#       Predicted Next_Tmin
# 0               24.333176
# 1               21.742869
# 2               23.606615
# 3               22.409665
# 4               23.021415
# ...                   ...
# 2272            23.754411
# 2273            24.858465
# 2274            24.334171
# 2275            21.155173
# 2276            24.170163
#
# [2277 rows x 4 columns]

# %%
# Results show that accuracy is very good

# %%
multiple_linear_reg = LinearRegression(fit_intercept = False)
multiple_linear_reg.fit(X_train,y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
from sklearn.preprocessing import PolynomialFeatures

polynomial_features = PolynomialFeatures(degree=2)
X_train_poly = polynomial_features.fit_transform(X_train)
X_test_poly = polynomial_features.fit_transform(X_test)

polynomial_reg = LinearRegression(fit_intercept = False)
polynomial_reg.fit(X_train_poly,y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree_reg = DecisionTreeRegressor(max_depth = 5, random_state=13)
decision_tree_reg.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=13)

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest_reg = RandomForestRegressor(n_estimators = 400, max_depth = 5, random_state=13)
random_forest_reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=400, random_state=13)

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR
support_vector = SVR(gamma='auto',kernel = 'linear',C=1)

support_vector_reg = MultiOutputRegressor(support_vector)

support_vector_reg.fit(X_train,y_train)
# Out:
# MultiOutputRegressor(estimator=SVR(C=1, gamma='auto', kernel='linear'))

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # Evaluating Multiple Linear Regression Model

# %%
# Predictions with training dataset
y_pred_MLR_train = multiple_linear_reg.predict(X_train)

# Predictions with testing dataset
y_pred_MLR_test = multiple_linear_reg.predict(X_test)

# Training accuracy for the model
accuracy_MLR_train = r2_score(y_train, y_pred_MLR_train)
print("Training accuracy for Multiple Linear Regression model: ", accuracy_MLR_train)

# Testing accuracy for the model
accuracy_MLR_test = r2_score(y_test,y_pred_MLR_test)
print("Testing accuracy for Multiple Linear Regression model: ", accuracy_MLR_test)

# RMSE for training data
RMSE_MLR_train = sqrt(mean_squared_error(y_train,y_pred_MLR_train))
print("RMSE for training data:", RMSE_MLR_train)

# RMSE for testing data
RMSE_MLR_test = sqrt(mean_squared_error(y_test,y_pred_MLR_test))
print("RMSE for testing data:", RMSE_MLR_test)

# Predictions with 10-Fold Cross Validation
y_pred_cv_MLR = cross_val_predict(multiple_linear_reg, X, y,cv=10)

# Accuracy after 10 - FOld Cross Validation
accuracy_cv_MLR = r2_score(y,y_pred_cv_MLR)
print("Accuracy for 10-Fold Cross Predicted MLR model: ", accuracy_cv_MLR)
# Out:
# Training accuracy for Multiple Linear Regression model:  0.806870866314611
# Testing accuracy for Multiple Linear Regression model:  0.8071651284573
# RMSE for training data: 1.26073545099891
# RMSE for testing data: 1.2464717802614755
# Accuracy for 10-Fold Cross Predicted MLR model:  0.7867662853650961

# %% [markdown]
# # Evaluating Polynomial Regression Model

# %%
# Predictions with training dataset
y_pred_PR_train = polynomial_reg.predict(X_train_poly)

# Predictions with testing dataset
y_pred_PR_test = polynomial_reg.predict(X_test_poly)

# Training accuracy for the model
accuracy_PR_train = r2_score(y_train, y_pred_PR_train)
print("Training accuracy for Polynomial Regression model: ", accuracy_PR_train)

# Testing accuracy for the model
accuracy_PR_test = r2_score(y_test,y_pred_PR_test)
print("Testing accuracy for Polynomial Regression model: ", accuracy_PR_test)

# RMSE for training data
RMSE_PR_train = sqrt(mean_squared_error(y_train,y_pred_PR_train))
print("RMSE for training data:", RMSE_MLR_train)

# RMSE for testing data
RMSE_PR_test = sqrt(mean_squared_error(y_test,y_pred_PR_test))
print("RMSE for testing data:", RMSE_PR_test)
# Out:
# Training accuracy for Polynomial Regression model:  0.8851205811887677
# Testing accuracy for Polynomial Regression model:  0.8701456664105043
# RMSE for training data: 1.26073545099891
# RMSE for testing data: 1.0178193807421665

# %% [markdown]
# # Evaluating Decision Tree Regressor Model

# %%
# Predictions with training dataset
y_pred_DTR_train = decision_tree_reg.predict(X_train)

# Predictions with testing dataset
y_pred_DTR_test = decision_tree_reg.predict(X_test)

# Training accuracy for the model
accuracy_DTR_train = r2_score(y_train, y_pred_DTR_train)
print("Training accuracy for Decision Tree Regression model: ", accuracy_DTR_train)

# Testing accuracy for the model
accuracy_DTR_test = r2_score(y_test,y_pred_DTR_test)
print("Testing accuracy for Decision Tree Regression model: ", accuracy_DTR_test)

# RMSE for training data
RMSE_DTR_train = sqrt(mean_squared_error(y_train,y_pred_DTR_train))
print("RMSE for training data:", RMSE_DTR_train)

# RMSE for testing data
RMSE_DTR_test = sqrt(mean_squared_error(y_test,y_pred_DTR_test))
print("RMSE for testing data:", RMSE_DTR_test)

# Predictions with 10-Fold Cross Validation
y_pred_cv_DTR = cross_val_predict(decision_tree_reg, X, y, cv=10)

# Accuracy after 10 - FOld Cross Validation
accuracy_cv_DTR = r2_score(y,y_pred_cv_DTR)
print("Accuracy for 10-Fold Cross Predicted DTR model: ", accuracy_cv_DTR)
# Out:
# Training accuracy for Decision Tree Regression model:  0.7552403048923747
# Testing accuracy for Decision Tree Regression model:  0.7239864409558011
# RMSE for training data: 1.3985976810978311
# RMSE for testing data: 1.4753360066732668
# Accuracy for 10-Fold Cross Predicted DTR model:  0.6725607559398621

# %% [markdown]
# # Evaluating Random Forest Regressor Model

# %%
# Predictions with training dataset
y_pred_RFR_train = random_forest_reg.predict(X_train)

# Predictions with testing dataset
y_pred_RFR_test = random_forest_reg.predict(X_test)

# Training accuracy for the model
accuracy_RFR_train = r2_score(y_train, y_pred_RFR_train)
print("Training accuracy for Random Forest Regression model: ", accuracy_RFR_train)

# Testing accuracy for the model
accuracy_RFR_test = r2_score(y_test,y_pred_RFR_test)
print("Testing accuracy for Random Forest Regression model: ", accuracy_RFR_test)

# RMSE for training data
RMSE_RFR_train = sqrt(mean_squared_error(y_train,y_pred_RFR_train))
print("RMSE for training data:", RMSE_RFR_train)

# RMSE for testing data
RMSE_RFR_test = sqrt(mean_squared_error(y_test,y_pred_RFR_test))
print("RMSE for testing data:", RMSE_RFR_test)

# Predictions with 10-Fold Cross Validation
y_pred_cv_RFR = cross_val_predict(random_forest_reg, X, y, cv=10)

# Accuracy after 10 - FOld Cross Validation
accuracy_cv_RFR = r2_score(y,y_pred_cv_RFR)
print("Accuracy for 10-Fold Cross Predicted DTR model: ", accuracy_cv_RFR)
# Out:
# Training accuracy for Random Forest Regression model:  0.7912398924336805
# Testing accuracy for Random Forest Regression model:  0.771632841946712
# RMSE for training data: 1.293930720175974
# RMSE for testing data: 1.3391617164038618
# Accuracy for 10-Fold Cross Predicted DTR model:  0.7284655418146931

# %% [markdown]
# # Evaluating Support Vector Regression Model

# %%
# Predictions with training dataset
y_pred_SVR_train = support_vector_reg.predict(X_train)

# Predictions with testing dataset
y_pred_SVR_test = support_vector_reg.predict(X_test)

# Training accuracy for the model
accuracy_SVR_train = r2_score(y_train, y_pred_SVR_train)
print("Training accuracy for Support Vector Regression model: ", accuracy_SVR_train)

# Testing accuracy for the model
accuracy_SVR_test = r2_score(y_test,y_pred_SVR_test)
print("Testing accuracy for Support Vector Regression model: ", accuracy_SVR_test)

# RMSE for training data
RMSE_SVR_train = sqrt(mean_squared_error(y_train,y_pred_SVR_train))
print("RMSE for training data:", RMSE_SVR_train)

# RMSE for testing data
RMSE_SVR_test = sqrt(mean_squared_error(y_test,y_pred_SVR_test))
print("RMSE for testing data:", RMSE_SVR_test)

# Predictions with 10-Fold Cross Validation
y_pred_cv_SVR = cross_val_predict(support_vector_reg, X, y, cv=2)

# Accuracy after 10 - FOld Cross Validation
accuracy_cv_SVR = r2_score(y,y_pred_cv_SVR)
print("Accuracy for 10-Fold Cross Predicted DTR model: ", accuracy_cv_SVR)
# Out:
# Training accuracy for Support Vector Regression model:  -2.030431618228608
# Testing accuracy for Support Vector Regression model:  -2.134859157026859
# RMSE for training data: 4.960644504568342
# RMSE for testing data: 4.992693920201105
# Accuracy for 10-Fold Cross Predicted DTR model:  -2.645667304232438

# %%
# Compare all results in one table
training_accuracies = [accuracy_MLR_train, accuracy_PR_train, accuracy_DTR_train, accuracy_RFR_train, accuracy_SVR_train]
testing_accuracies = [accuracy_MLR_test, accuracy_PR_test, accuracy_DTR_test, accuracy_RFR_test, accuracy_SVR_test]
training_RMSE = [RMSE_MLR_train, RMSE_PR_train, RMSE_DTR_train, RMSE_RFR_train, RMSE_SVR_train]
testing_RMSE = [RMSE_MLR_test, RMSE_PR_test, RMSE_DTR_test, RMSE_RFR_test, RMSE_SVR_test]


parameters = ["fit_intercept=False", "fit_intercept=False", "max_depth=5", "n_estimators=400, max_depth=5", "kernel=”linear”, C=1000"]

table_data = {"Parameters": parameters, "Training Accuracy": training_accuracies, "Testing Accuracy": testing_accuracies, 
              "Training RMSE": training_RMSE, "Testing RMSE": testing_RMSE}
model_names = ["Multiple Linear Regression", "Polynomial Regression", "Decision Tree Regression", "Random Forest Regression", "Support Vector Regression"]

table_dataframe = pd.DataFrame(data=table_data, index=model_names)
table_dataframe
# Out:
#                                                Parameters  Training Accuracy  \
# Multiple Linear Regression            fit_intercept=False           0.806871
# Polynomial Regression                 fit_intercept=False           0.885121
# Decision Tree Regression                      max_depth=5           0.755240
# Random Forest Regression    n_estimators=400, max_depth=5           0.791240
# Support Vector Regression         kernel=”linear”, C=1000          -2.030432
#
#                             Testing Accuracy  Training RMSE  Testing RMSE
# Multiple Linear Regression          0.807165       1.260735      1.246472
# Polynomial Regression               0.870146       0.969037      1.017819
# Decision Tree Regression            0.723986       1.398598      1.475336
# Random Forest Regression            0.771633       1.293931      1.339162
# Support Vector Regression          -2.134859       4.960645      4.992694

# %%
# Polynomial Regression gives the highest accuracy score so that model can be used for modelling
